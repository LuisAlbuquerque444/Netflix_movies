# %% [markdown]
# ![Movie popcorn on red background](redpopcorn.jpg)

# %% [markdown]
# **Netflix**! What started in 1997 as a DVD rental service has since exploded into one of the largest entertainment and media companies.
#
# Given the large number of movies and series available on the platform, it is a perfect opportunity to flex your exploratory data analysis skills and dive into the entertainment industry. Our friend has also been brushing up on their Python skills and has taken a first crack at a CSV file containing Netflix data. They believe that the average duration of movies has been declining. Using your friends initial research, you'll delve into the Netflix data to see if you can determine whether movie lengths are actually getting shorter and explain some of the contributing factors, if any.
#
# You have been supplied with the dataset `netflix_data.csv` , along with the following table detailing the column names and descriptions. This data does contain null values and some outliers, but handling these is out of scope for the project. Feel free to experiment after submitting!
#
# ## The data
# ### **netflix_data.csv**
# | Column | Description |
# |--------|-------------|
# | `show_id` | The ID of the show |
# | `type` | Type of show |
# | `title` | Title of the show |
# | `director` | Director of the show |
# | `cast` | Cast of the show |
# | `country` | Country of origin |
# | `date_added` | Date added to Netflix |
# | `release_year` | Year of Netflix release |
# | `duration` | Duration of the show in minutes |
# | `description` | Description of the show |
# | `genre` | Show genre |

# %%
# Importing pandas and matplotlib
import pandas as pd
import matplotlib.pyplot as plt

# Start coding!

# Corrected code to read a CSV file into a DataFrame
netflix_df = pd.DataFrame( pd.read_csv('netflix_data.csv') )
netflix_subset = netflix_df[netflix_df['type']== 'Movie']
netflix_movies = netflix_subset[["title","country","genre","release_year","duration"]] 
short_movies = netflix_movies[ netflix_movies['duration'] < 60   ]

colors = []
for label,row in netflix_movies.iterrows():

    if col == 'Children':
        colors.append('Blue')
    elif col == 'Documentaries':
        colors.append('Red')
    elif col == 'Stand-Up':
        colors.append('Green')
    else:
        colors.append('Yellow')
print(color)


fig = plt.figure(figsize=(12,8))

plt.scatter(netflix_movies['release_year'],netflix_movies
['duration'],color = colors)
plt.title("Movie Duration by Year of Release")
plt.xlabel("Release year")
plt.ylabel("Duration (min)")

plt.show()

answer = 'no'
# Out:
# ['Red', 'Yellow', 'Yellow', 'Red', 'Red', 'Yellow', 'Yellow', 'Blue', 'Blue', 'Blue', 'Red', 'Red', 'Green', 'Blue', 'Red', 'Blue', 'Yellow', 'Blue', 'Yellow', 'Green', 'Green', 'Red', 'Red', 'Yellow', 'Green', 'Green', 'Red', 'Blue', 'Red', 'Blue', 'Blue', 'Red', 'Red', 'Red', 'Red', 'Red', 'Green', 'Blue', 'Blue', 'Yellow', 'Green', 'Green', 'Red', 'Green', 'Yellow', 'Red', 'Blue', 'Blue', 'Blue', 'Green', 'Red', 'Red', 'Red', 'Green', 'Red', 'Green', 'Red', 'Blue', 'Yellow', 'Red', 'Green', 'Yellow', 'Blue', 'Blue', 'Blue', 'Blue', 'Blue', 'Blue', 'Green', 'Green', 'Blue', 'Blue', 'Blue', 'Yellow', 'Green', 'Green', 'Red', 'Red', 'Yellow', 'Yellow', 'Red', 'Red', 'Red', 'Green', 'Green', 'Red', 'Green', 'Blue', 'Yellow', 'Green', 'Yellow', 'Blue', 'Blue', 'Blue', 'Blue', 'Blue', 'Blue', 'Red', 'Blue', 'Red', 'Green', 'Red', 'Blue', 'Blue', 'Red', 'Red', 'Red', 'Green', 'Red', 'Red', 'Green', 'Red', 'Yellow', 'Green', 'Blue', 'Red', 'Red', 'Green', 'Yellow', 'Blue', 'Blue', 'Red', 'Yellow', 'Yellow', 'Green', 'Green', 'Green', 'Yellow', 'Blue', 'Yellow', 'Yellow', 'Red', 'Green', 'Blue', 'Yellow', 'Yellow', 'Red', 'Red', 'Green', 'Red', 'Red', 'Red', 'Red', 'Red', 'Red', 'Yellow', 'Red', 'Green', 'Red', 'Yellow', 'Green', 'Green', 'Red', 'Red', 'Green', 'Green', 'Red', 'Red', 'Yellow', 'Green', 'Green', 'Green', 'Red', 'Red', 'Blue', 'Blue', 'Blue', 'Blue', 'Yellow', 'Yellow', 'Red', 'Red', 'Blue', 'Yellow', 'Yellow', 'Blue', 'Yellow', 'Red', 'Blue', 'Blue', 'Blue', 'Blue', 'Yellow', 'Blue', 'Red', 'Yellow', 'Red', 'Red', 'Green', 'Blue', 'Blue', 'Blue', 'Red', 'Red', 'Red', 'Green', 'Green', 'Red', 'Yellow', 'Red', 'Red', 'Green', 'Yellow', 'Green', 'Blue', 'Yellow', 'Red', 'Green', 'Green', 'Red', 'Yellow', 'Red', 'Green', 'Blue', 'Green', 'Green', 'Yellow', 'Red', 'Blue', 'Blue', 'Blue', 'Blue', 'Blue', 'Red', 'Yellow', 'Yellow', 'Blue', 'Blue', 'Blue', 'Yellow', 'Red', 'Red', 'Yellow', 'Yellow', 'Red', 'Blue', 'Red', 'Red', 'Red', 'Red', 'Red', 'Red', 'Red', 'Red', 'Red', 'Red', 'Red', 'Red', 'Red', 'Red', 'Red', 'Yellow', 'Red', 'Blue', 'Yellow', 'Yellow', 'Yellow', 'Red', 'Yellow', 'Yellow', 'Yellow', 'Red', 'Green', 'Yellow', 'Yellow', 'Yellow', 'Yellow', 'Yellow', 'Yellow', 'Yellow', 'Yellow', 'Blue', 'Yellow', 'Yellow', 'Blue', 'Yellow', 'Blue', 'Blue', 'Yellow', 'Blue', 'Blue', 'Yellow', 'Red', 'Green', 'Red', 'Red', 'Red', 'Red', 'Red', 'Red', 'Red', 'Red', 'Green', 'Green', 'Green', 'Green', 'Red', 'Blue', 'Yellow', 'Blue', 'Red', 'Green', 'Green', 'Green', 'Red', 'Yellow', 'Yellow', 'Yellow', 'Red', 'Green', 'Green', 'Red', 'Red', 'Red', 'Red', 'Red', 'Red', 'Red', 'Red', 'Red', 'Red', 'Blue', 'Yellow', 'Blue', 'Green', 'Blue', 'Red', 'Yellow', 'Blue', 'Yellow', 'Blue', 'Blue', 'Blue', 'Red', 'Blue', 'Yellow', 'Blue', 'Blue', 'Blue', 'Blue', 'Blue', 'Blue', 'Blue', 'Blue', 'Blue', 'Blue', 'Blue', 'Yellow', 'Red', 'Red', 'Red', 'Red', 'Yellow', 'Yellow', 'Yellow', 'Red', 'Red', 'Red', 'Yellow', 'Yellow', 'Yellow', 'Blue', 'Blue', 'Blue', 'Blue', 'Yellow', 'Red', 'Red', 'Yellow', 'Yellow', 'Red', 'Red', 'Red', 'Red', 'Red', 'Blue', 'Red', 'Red', 'Red', 'Red', 'Red', 'Red', 'Blue', 'Blue', 'Blue', 'Yellow', 'Green', 'Green', 'Green', 'Green', 'Green', 'Green', 'Green', 'Yellow', 'Yellow', 'Blue', 'Blue', 'Blue', 'Blue', 'Yellow', 'Blue', 'Blue', 'Blue', 'Red', 'Yellow', 'Green', 'Red', 'Red', 'Yellow', 'Red', 'Red', 'Green', 'Green', 'Red', 'Yellow', 'Red', 'Red', 'Green', 'Red', 'Red']
